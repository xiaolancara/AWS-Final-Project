# %%
import pandas as pd
from sodapy import Socrata
import datetime

# %%
client = Socrata('data.cityofnewyork.us',
                 'Tarfn2kl2IdBRX1RkC5rhcoOh',
                 timeout = 150
                )
Previous_twoday = str(datetime.datetime.today() - datetime.timedelta(days=2))[:19]
Previous_twoday = Previous_twoday[:10] + 'T' + Previous_twoday[11:]
Previous_oneday = str(datetime.datetime.today() - datetime.timedelta(days=1))[:19]
Previous_oneday = Previous_oneday[:10] + 'T' + Previous_oneday[11:]
response = client.get("erm2-nwe9", where="created_date BETWEEN '"+Previous_twoday+"' AND '"+Previous_oneday+"'", limit=10000)
results_df = pd.DataFrame.from_records(response)
client.close()
print('Successfully getting create time from \'{}\' to \'{}\''.format(Previous_twoday, Previous_oneday))
results_df
# Out:
# Successfully getting create time from '2021-07-20T20:34:30' to '2021-07-21T20:34:30'
#      unique_key             created_date agency  \
# 0      51268623  2021-07-20T20:34:30.000   NYPD
# 1      51274367  2021-07-20T20:34:40.000   NYPD
# 2      51271255  2021-07-20T20:34:42.000  DOHMH
# 3      51275757  2021-07-20T20:35:00.000    DEP
# 4      51273352  2021-07-20T20:35:32.000   NYPD
# ...         ...                      ...    ...
# 2179   51265504  2021-07-21T02:06:34.000   NYPD
# 2180   51264702  2021-07-21T02:07:12.000   NYPD
# 2181   51272961  2021-07-21T02:07:33.000   NYPD
# 2182   51266003  2021-07-21T02:07:34.000   NYPD
# 2183   51274333  2021-07-21T02:08:32.000   NYPD
#
#                                   agency_name           complaint_type  \
# 0             New York City Police Department      Noise - Residential
# 1             New York City Police Department      Noise - Residential
# 2     Department of Health and Mental Hygiene                   Rodent
# 3      Department of Environmental Protection             Water System
# 4             New York City Police Department          Illegal Parking
# ...                                       ...                      ...
# 2179          New York City Police Department  Noise - Street/Sidewalk
# 2180          New York City Police Department      Noise - Residential
# 2181          New York City Police Department      Noise - Residential
# 2182          New York City Police Department         Blocked Driveway
# 2183          New York City Police Department      Noise - Residential
#
#                         descriptor               location_type incident_zip  \
# 0                 Loud Music/Party  Residential Building/House        10466
# 1                 Loud Music/Party  Residential Building/House        10466
# 2                     Rat Sighting         Commercial Building        11222
# 3       Hydrant Running Full (WA4)                         NaN        10467
# 4     Commercial Overnight Parking             Street/Sidewalk        11369
# ...                            ...                         ...          ...
# 2179              Loud Music/Party             Street/Sidewalk        11233
# 2180              Loud Music/Party  Residential Building/House        10466
# 2181              Banging/Pounding  Residential Building/House        10028
# 2182                     No Access             Street/Sidewalk        11372
# 2183              Loud Music/Party  Residential Building/House        10466
#
#                  incident_address              street_name  ... address_type  \
# 0            672 EAST  231 STREET         EAST  231 STREET  ...          NaN
# 1            672 EAST  231 STREET         EAST  231 STREET  ...          NaN
# 2           1110 MANHATTAN AVENUE         MANHATTAN AVENUE  ...          NaN
# 3             3525 DECATUR AVENUE           DECATUR AVENUE  ...      ADDRESS
# 4           27-45 MCINTOSH STREET          MCINTOSH STREET  ...          NaN
# ...                           ...                      ...  ...          ...
# 2179  173 THOMAS S BOYLAND STREET  THOMAS S BOYLAND STREET  ...          NaN
# 2180         672 EAST  231 STREET         EAST  231 STREET  ...          NaN
# 2181                1579 2 AVENUE                 2 AVENUE  ...          NaN
# 2182              35-31 86 STREET                86 STREET  ...          NaN
# 2183         672 EAST  231 STREET         EAST  231 STREET  ...          NaN
#
#                                  resolution_description  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     The Department of Environmental Protection det...
# 4     The Police Department responded to the complai...
# ...                                                 ...
# 2179                                                NaN
# 2180  The Police Department responded to the complai...
# 2181                                                NaN
# 2182                                                NaN
# 2183                                                NaN
#
#      resolution_action_updated_date facility_type bridge_highway_name  \
# 0                               NaN           NaN                 NaN
# 1                               NaN           NaN                 NaN
# 2                               NaN           NaN                 NaN
# 3           2021-07-20T20:35:00.000           NaN                 NaN
# 4           2021-07-21T00:53:32.000           NaN                 NaN
# ...                             ...           ...                 ...
# 2179                            NaN           NaN                 NaN
# 2180        2021-07-21T02:07:47.000           NaN                 NaN
# 2181                            NaN           NaN                 NaN
# 2182                            NaN           NaN                 NaN
# 2183                            NaN           NaN                 NaN
#
#      bridge_highway_segment taxi_pick_up_location taxi_company_borough  \
# 0                       NaN                   NaN                  NaN
# 1                       NaN                   NaN                  NaN
# 2                       NaN                   NaN                  NaN
# 3                       NaN                   NaN                  NaN
# 4                       NaN                   NaN                  NaN
# ...                     ...                   ...                  ...
# 2179                    NaN                   NaN                  NaN
# 2180                    NaN                   NaN                  NaN
# 2181                    NaN                   NaN                  NaN
# 2182                    NaN                   NaN                  NaN
# 2183                    NaN                   NaN                  NaN
#
#      bridge_highway_direction due_date
# 0                         NaN      NaN
# 1                         NaN      NaN
# 2                         NaN      NaN
# 3                         NaN      NaN
# 4                         NaN      NaN
# ...                       ...      ...
# 2179                      NaN      NaN
# 2180                      NaN      NaN
# 2181                      NaN      NaN
# 2182                      NaN      NaN
# 2183                      NaN      NaN
#
# [2184 rows x 39 columns]
